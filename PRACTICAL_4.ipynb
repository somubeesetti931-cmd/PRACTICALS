# %%
import time

# Iterative method
def factorial_iterative(n):
    fact = 1
    for i in range(1, n + 1):
        fact = fact * i
    return fact


# Recursive method
def factorial_recursive(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial_recursive(n - 1)


# User input
n = int(input("Enter a number: "))

if n < 0:
    print("Factorial is not defined for negative numbers.")
else:
    # Iterative execution time
    start_time = time.perf_counter()
    result_iterative = factorial_iterative(n)
    end_time = time.perf_counter()
    iterative_time = end_time - start_time

    # Recursive execution time
    start_time = time.perf_counter()
    result_recursive = factorial_recursive(n)
    end_time = time.perf_counter()
    recursive_time = end_time - start_time

    # Display results
    print("\n--- Iterative Method ---")
    print("Factorial =", result_iterative)
    print("Execution Time =", iterative_time, "seconds")
    print("Time Complexity = O(n)")
    print("Space Complexity = O(1)")

    print("\n--- Recursive Method ---")
    print("Factorial =", result_recursive)
    print("Execution Time =", recursive_time, "seconds")
    print("Time Complexity = O(n)")
    print("Space Complexity = O(n)")
# Out:
# Enter a number: 5
#
# --- Iterative Method ---
# Factorial = 120
# Execution Time = 4.354999873612542e-06 seconds
# Time Complexity = O(n)
# Space Complexity = O(1)
#
# --- Recursive Method ---
# Factorial = 120
# Execution Time = 2.539999968576012e-06 seconds
# Time Complexity = O(n)
# Space Complexity = O(n)
